# %%
import pandas as pd

medical_df = pd.read_csv('Dataset/medical.csv')
print("Medical Dataset - First 5 rows:")
print(medical_df.head())
print("\nDataset Info:")
print(medical_df.info())
print("\nDataset Shape:", medical_df.shape)
